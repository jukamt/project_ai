# %% [markdown]
# <a href="https://colab.research.google.com/github/jukamt/project_ai/blob/main/Fruit_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from random import randint
from keras.utils import np_utils
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train=ImageDataGenerator(rescale=1/255)
validation=ImageDataGenerator(rescale=1/255)
training_set=train.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/FRUIT/train/train',target_size=(150,150), batch_size=1, class_mode='categorical')
validation_set=validation.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/FRUIT/train/validation',target_size=(150,150), batch_size=1, class_mode='categorical')
# Out:
# Found 120 images belonging to 6 classes.
# Found 120 images belonging to 6 classes.

# %%
training_set.class_indices
# Out:
# {'buoi': 0, 'cam': 1, 'coc': 2, 'khe': 3, 'mit': 4, 'xoai': 5}

# %%
#Tạo Model
model = Sequential()

model.add(Conv2D(16,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(1024,activation='relu',kernel_initializer='he_normal'))
model.add(Dense(6,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 1024)              10617856
#
#  dense_1 (Dense)             (None, 6)                 6150
#
# =================================================================
# Total params: 10,721,446
# Trainable params: 10,721,446
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=RMSprop(),loss='categorical_crossentropy',  metrics=['accuracy'])
from keras.callbacks import EarlyStopping
history = model.fit(training_set, epochs = 100, batch_size=120, validation_data = validation_set, verbose=1, callbacks=[EarlyStopping(monitor='val_loss', patience=50)])
# Out:
# Epoch 1/100
# 120/120 [==============================] - 134s 1s/step - loss: 23.1476 - accuracy: 0.3583 - val_loss: 3.4420 - val_accuracy: 0.4250
# Epoch 2/100
# 120/120 [==============================] - 2s 20ms/step - loss: 5.1106 - accuracy: 0.6083 - val_loss: 2.1653 - val_accuracy: 0.5917
# Epoch 3/100
# 120/120 [==============================] - 2s 20ms/step - loss: 4.2382 - accuracy: 0.7250 - val_loss: 1.6208 - val_accuracy: 0.6583
# Epoch 4/100
# 120/120 [==============================] - 2s 20ms/step - loss: 4.4721 - accuracy: 0.7167 - val_loss: 4.2964 - val_accuracy: 0.5583
# Epoch 5/100
# 120/120 [==============================] - 2s 20ms/step - loss: 2.8497 - accuracy: 0.8583 - val_loss: 1.9913 - val_accuracy: 0.7750
# Epoch 6/100
# 120/120 [==============================] - 2s 20ms/step - loss: 2.1863 - accuracy: 0.8500 - val_loss: 17.3927 - val_accuracy: 0.3333
# Epoch 7/100
# 120/120 [==============================] - 2s 21ms/step - loss: 3.9608 - accuracy: 0.8583 - val_loss: 4.2628 - val_accuracy: 0.6750
# Epoch 8/100
# 120/120 [==============================] - 2s 20ms/step - loss: 2.1968 - accuracy: 0.8917 - val_loss: 7.8024 - val_accuracy: 0.3917
# Epoch 9/100
# 120/120 [==============================] - 3s 21ms/step - loss: 1.4493 - accuracy: 0.8833 - val_loss: 1.5284 - val_accuracy: 0.8583
# Epoch 10/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.7298 - accuracy: 0.9667 - val_loss: 6.7691 - val_accuracy: 0.6083
# Epoch 11/100
# 120/120 [==============================] - 3s 21ms/step - loss: 2.4446 - accuracy: 0.9000 - val_loss: 3.4639 - val_accuracy: 0.7167
# Epoch 12/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.6936 - accuracy: 0.9583 - val_loss: 2.4535 - val_accuracy: 0.7500
# Epoch 13/100
# 120/120 [==============================] - 3s 21ms/step - loss: 1.3222 - accuracy: 0.8917 - val_loss: 6.0483 - val_accuracy: 0.6583
# Epoch 14/100
# 120/120 [==============================] - 2s 20ms/step - loss: 1.2217 - accuracy: 0.9667 - val_loss: 1.6230 - val_accuracy: 0.7500
# Epoch 15/100
# 120/120 [==============================] - 2s 21ms/step - loss: 2.0131 - accuracy: 0.9333 - val_loss: 2.1607 - val_accuracy: 0.7917
# Epoch 16/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.4073 - accuracy: 0.9667 - val_loss: 4.4665 - val_accuracy: 0.7250
# Epoch 17/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.2585 - accuracy: 0.9750 - val_loss: 4.1103 - val_accuracy: 0.7250
# Epoch 18/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.9584 - accuracy: 0.9583 - val_loss: 1.9958 - val_accuracy: 0.8083
# Epoch 19/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.4980 - accuracy: 0.9667 - val_loss: 2.1895 - val_accuracy: 0.7750
# Epoch 20/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.6685 - accuracy: 0.9333 - val_loss: 2.8614 - val_accuracy: 0.6583
# Epoch 21/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.4450 - accuracy: 0.9583 - val_loss: 1.5094 - val_accuracy: 0.7500
# Epoch 22/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.6859 - accuracy: 0.9583 - val_loss: 3.9104 - val_accuracy: 0.5917
# Epoch 23/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.4126 - accuracy: 0.9583 - val_loss: 2.6999 - val_accuracy: 0.8250
# Epoch 24/100
# 120/120 [==============================] - 2s 20ms/step - loss: 1.3834 - accuracy: 0.9500 - val_loss: 5.2207 - val_accuracy: 0.6083
# Epoch 25/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.4290 - accuracy: 0.9583 - val_loss: 2.9143 - val_accuracy: 0.7500
# Epoch 26/100
# 120/120 [==============================] - 2s 20ms/step - loss: 2.3918 - accuracy: 0.9417 - val_loss: 4.8335 - val_accuracy: 0.7167
# Epoch 27/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.4621 - accuracy: 0.9500 - val_loss: 5.2532 - val_accuracy: 0.6583
# Epoch 28/100
# 120/120 [==============================] - 2s 20ms/step - loss: 1.1211 - accuracy: 0.9500 - val_loss: 2.3899 - val_accuracy: 0.7750
# Epoch 29/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.9205 - accuracy: 0.9417 - val_loss: 4.3389 - val_accuracy: 0.7917
# Epoch 30/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.7788 - accuracy: 0.9667 - val_loss: 4.4742 - val_accuracy: 0.7250
# Epoch 31/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.5120 - accuracy: 0.9583 - val_loss: 4.0429 - val_accuracy: 0.7833
# Epoch 32/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.2665 - accuracy: 0.9833 - val_loss: 11.5925 - val_accuracy: 0.5417
# Epoch 33/100
# 120/120 [==============================] - 2s 20ms/step - loss: 1.4424 - accuracy: 0.9250 - val_loss: 6.0203 - val_accuracy: 0.8250
# Epoch 34/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.9189 - accuracy: 0.9417 - val_loss: 11.2933 - val_accuracy: 0.5667
# Epoch 35/100
# 120/120 [==============================] - 2s 20ms/step - loss: 1.6920 - accuracy: 0.9500 - val_loss: 2.5593 - val_accuracy: 0.8333
# Epoch 36/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.1497 - accuracy: 0.9917 - val_loss: 6.5403 - val_accuracy: 0.6333
# Epoch 37/100
# 120/120 [==============================] - 2s 20ms/step - loss: 1.9359 - accuracy: 0.9500 - val_loss: 2.5109 - val_accuracy: 0.7917
# Epoch 38/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.6717 - accuracy: 0.9583 - val_loss: 3.3971 - val_accuracy: 0.7750
# Epoch 39/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.4635 - accuracy: 0.9667 - val_loss: 3.1900 - val_accuracy: 0.7000
# Epoch 40/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.2290 - accuracy: 0.9667 - val_loss: 6.1544 - val_accuracy: 0.6417
# Epoch 41/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.2486 - accuracy: 0.9667 - val_loss: 5.0921 - val_accuracy: 0.7083
# Epoch 42/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.1831 - accuracy: 0.9667 - val_loss: 4.4846 - val_accuracy: 0.7000
# Epoch 43/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0741 - accuracy: 0.9917 - val_loss: 9.8653 - val_accuracy: 0.6750
# Epoch 44/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.3785 - accuracy: 0.9417 - val_loss: 10.4635 - val_accuracy: 0.6333
# Epoch 45/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.8245 - accuracy: 0.9667 - val_loss: 3.7212 - val_accuracy: 0.7667
# Epoch 46/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.1625 - accuracy: 0.9750 - val_loss: 3.7265 - val_accuracy: 0.8000
# Epoch 47/100
# 120/120 [==============================] - 2s 21ms/step - loss: 1.1335 - accuracy: 0.9667 - val_loss: 6.2113 - val_accuracy: 0.7333
# Epoch 48/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.6821 - accuracy: 0.9750 - val_loss: 6.0904 - val_accuracy: 0.7167
# Epoch 49/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.1905 - accuracy: 0.9750 - val_loss: 12.9866 - val_accuracy: 0.6500
# Epoch 50/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.9060 - accuracy: 0.9417 - val_loss: 10.0716 - val_accuracy: 0.7083
# Epoch 51/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.6335 - accuracy: 0.9333 - val_loss: 6.7867 - val_accuracy: 0.7750
# Epoch 52/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.2795 - accuracy: 0.9667 - val_loss: 9.7505 - val_accuracy: 0.7500
# Epoch 53/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.9756 - accuracy: 0.9583 - val_loss: 9.4968 - val_accuracy: 0.7083
# Epoch 54/100
# 120/120 [==============================] - 2s 20ms/step - loss: 1.2467 - accuracy: 0.9167 - val_loss: 4.5775 - val_accuracy: 0.7667
# Epoch 55/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.2385 - accuracy: 0.9667 - val_loss: 5.2420 - val_accuracy: 0.6750
# Epoch 56/100
# 120/120 [==============================] - 2s 20ms/step - loss: 2.5080 - accuracy: 0.9667 - val_loss: 5.1092 - val_accuracy: 0.7500
# Epoch 57/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.2783 - accuracy: 0.9833 - val_loss: 5.4642 - val_accuracy: 0.7667
# Epoch 58/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.3239 - accuracy: 0.9750 - val_loss: 6.5983 - val_accuracy: 0.6583
# Epoch 59/100
# 120/120 [==============================] - 3s 25ms/step - loss: 0.4054 - accuracy: 0.9667 - val_loss: 7.5230 - val_accuracy: 0.5833
# Epoch 60/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.3067 - accuracy: 0.9750 - val_loss: 4.2216 - val_accuracy: 0.7417
# Epoch 61/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.4962 - accuracy: 0.9750 - val_loss: 5.6760 - val_accuracy: 0.6500
# Epoch 62/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.2879 - accuracy: 0.9667 - val_loss: 3.5082 - val_accuracy: 0.7833
# Epoch 63/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.5107 - accuracy: 0.9833 - val_loss: 2.6573 - val_accuracy: 0.7667
# Epoch 64/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.3397 - accuracy: 0.9750 - val_loss: 2.7056 - val_accuracy: 0.8000
# Epoch 65/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.1743 - accuracy: 0.9833 - val_loss: 4.5004 - val_accuracy: 0.7167
# Epoch 66/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.3730 - accuracy: 0.9667 - val_loss: 3.5731 - val_accuracy: 0.7333
# Epoch 67/100
# 120/120 [==============================] - 2s 21ms/step - loss: 0.1803 - accuracy: 0.9583 - val_loss: 3.1036 - val_accuracy: 0.7750
# Epoch 68/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.1370 - accuracy: 0.9833 - val_loss: 3.6025 - val_accuracy: 0.7667
# Epoch 69/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.1010 - accuracy: 0.9750 - val_loss: 2.4639 - val_accuracy: 0.7583
# Epoch 70/100
# 120/120 [==============================] - 3s 21ms/step - loss: 0.1430 - accuracy: 0.9750 - val_loss: 6.6497 - val_accuracy: 0.7750
# Epoch 71/100
# 120/120 [==============================] - 2s 20ms/step - loss: 0.4037 - accuracy: 0.9750 - val_loss: 5.3364 - val_accuracy: 0.7000

# %%
score = model.evaluate(validation_set,verbose=0)
print('Sai số kiểm tra là: ',score[0])
print('Độ chính xác kiểm tra là: ',score[1])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()
# Out:
# Sai số kiểm tra là:  5.336398124694824
# Độ chính xác kiểm tra là:  0.699999988079071

# %%
model.save('model_save/CNN_Fruit.h5')

# %%
CNN_Fruit=load_model('model_save/CNN_Fruit.h5')
img_path = '/content/drive/MyDrive/Colab Notebooks/FRUIT/test/khe/Khe (10).jpg'
img=load_img(img_path,target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,150,150,3)
img=img.astype('float32')
img=img/255
pre=np.argmax(CNN_Fruit.predict(img),axis=1)
pred = model.predict(img)

classes = ['Buoi','Cam', 'Coc', 'Khe', 'Mit', 'Xoai']

# %%
print(np.argmax(pred))
if pre == 0:
  print(classes[0])
elif pre == 1:
    print(classes[1])
elif pre == 2:
    print(classes[2])
elif pre == 3:
    print(classes[3])
elif pre == 4:
    print(classes[4])
elif pre == 5 : 
  print(classes[5])
# Out:
# 3
# Khe
